# %%
# %pylab inline

# (c) 2014 Reid Johnson and Everaldo Aguiar
#
# Functions to work with continuous data and linear regression models.

import matplotlib.pyplot as pl
import pandas as pd

def pairs(data):
    """Generates and shows a pairwise scatterplot of the dataset features.

    A figure with nxn scatterplots is generated, where n is the number of features. The features are
    defined as the all columns excluding the final column, which is defined as the class.

    Args:
      data (array): A dataset.

    """
    i = 1

    # Divide columns into features and class.
    features = list(data.columns)
    classes = features[-1] # create class column
    del features[-1] # delete class column from feature vector

    # Generate an nxn subplot figure, where n is the number of features.
    figure = pl.figure(figsize=(5*(len(data.columns)-1), 4*(len(data.columns)-1)))
    for col1 in data[features]:
        for col2 in data[features]:
            ax = pl.subplot(len(data.columns)-1, len(data.columns)-1, i)
            if col1 == col2:
                ax.text(2.5, 4.5, col1, style='normal', fontsize=20)
                ax.axis([0, 10, 0, 10])
                pl.xticks([]), pl.yticks([])
            else:
                for name in data[classes]:
                    cond = data[classes] == name
                    ax.plot(data[col2][cond], data[col1][cond], linestyle='none', marker='o', label=name)
                #t = plt.title(name)
            i += 1

    pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Load Iris Dataset
fileURL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(fileURL, names=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Species'], header=None)
iris = iris.dropna( )

# %%
# print(type(iris))
# print(iris)
# print(iris.head())
# print(list(iris.columns))
# print(iris.describe())
# shape
# print(iris.shape)
pairs(iris)

# %%
# Code source:https://github.com/scikit-learn/scikit-learn/blob/master/examples/linear_model/plot_ols.py

from sklearn import linear_model
from sklearn.model_selection  import train_test_split

def linear_reg(ft1, ft2, ft3):
    if (not ft3):
        iris_X = iris.as_matrix([ft1])
    else:
         iris_X = iris.as_matrix([ft1, ft3])
    iris_Y = iris.as_matrix([ft2])
    # Splitting the data with test szue : test train = 20:80, number 5 is passed as a seed generator
    iris_X_train, iris_X_test, iris_Y_train, iris_Y_test = train_test_split(iris_X, iris_Y, test_size=0.2, random_state=50)
    
    # Create Linear regression object
    regr = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regr.fit(iris_X_train, iris_Y_train)
    
    # The coefficients
    print('Coefficients: \n', regr.coef_)
    # The mean squared error
    print("Mean squared error: %.2f"
          % np.mean((regr.predict(iris_X_test) - iris_Y_test) ** 2))
    # Explained variance score: 1 is perfect prediction
    print('Variance score: %.2f' % regr.score(iris_X_test, iris_Y_test))

    # Plot outputs
    if (ft3 == None):
        plt.scatter(iris_X_test, iris_Y_test,  color='black')
        plt.plot(iris_X_test, regr.predict(iris_X_test), color='blue',
                 linewidth=3)

        plt.xticks(())
        plt.yticks(())

        plt.show()

# %%
# Petal Length and Petal Width 
linear_reg('Petal Length', 'Petal Width', None)
# Out:
# Coefficients:
#  [[0.41451925]]
# Mean squared error: 0.03
# Variance score: 0.94
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Petal Length and Sepal Length 
linear_reg('Petal Length', 'Sepal Length', None)
# Out:
# Coefficients:
#  [[0.40981724]]
# Mean squared error: 0.18
# Variance score: 0.72
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Petal Length and Sepal Width 
linear_reg('Petal Length', 'Sepal Width', None)
# Out:
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()
# Coefficients:
#  [[-0.10467012]]
# Mean squared error: 0.16
# Variance score: 0.16

# %%
# Petal Width and Sepal Length
linear_reg('Petal Width', 'Sepal Length', None)
# Out:
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()
# Coefficients:
#  [[0.89095165]]
# Mean squared error: 0.24
# Variance score: 0.62

# %%
# Petal Width and Sepal Width
linear_reg('Petal Width', 'Sepal Width', None)
# Out:
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()
# Coefficients:
#  [[-0.20648379]]
# Mean squared error: 0.17
# Variance score: 0.11

# %%
# Petal Width and Petal Length
linear_reg('Petal Width', 'Petal Length', None)
# Out:
# Coefficients:
#  [[2.22561136]]
# Mean squared error: 0.18
# Variance score: 0.94
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Width and Sepal Length
linear_reg('Sepal Width', 'Sepal Length', None)
# Out:
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()
# Coefficients:
#  [[-0.22269366]]
# Mean squared error: 0.71
# Variance score: -0.10

# %%
# Sepal Width and Petal Length
linear_reg('Sepal Width', 'Petal Length', None)
# Out:
# Coefficients:
#  [[-1.73469663]]
# Mean squared error: 2.69
# Variance score: 0.14
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Width and Petal Width
linear_reg('Sepal Width', 'Petal Width', None)
# Out:
# Coefficients:
#  [[-0.63735608]]
# Mean squared error: 0.54
# Variance score: 0.10
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Length and Petal Width
linear_reg('Sepal Length', 'Petal Width', None)
# Out:
# Coefficients:
#  [[0.75288365]]
# Mean squared error: 0.21
# Variance score: 0.66
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Length and Sepal Width
linear_reg('Sepal Length', 'Sepal Width', None)
# Out:
# Coefficients:
#  [[-0.06096568]]
# Mean squared error: 0.19
# Variance score: 0.00
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# THree features 
# Sepal Length, Petal Length -> Sepal Width
linear_reg('Sepal Length', 'Petal Length', 'Sepal Width')
# Out:
# Coefficients:
#  [[ 1.77776091 -1.33880055]]
# Mean squared error: 0.46
# Variance score: 0.85
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Length, Petal Width -> Petal Length
linear_reg('Sepal Length', 'Petal Length', 'Petal Width')
# Out:
# Coefficients:
#  [[0.55815873 1.72831893]]
# Mean squared error: 0.13
# Variance score: 0.96
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Length, Sepal Width -> Petal Length
linear_reg('Sepal Length', 'Sepal Width', 'Petal Length')
# Out:
# Coefficients:
#  [[ 0.56159583 -0.33482177]]
# Mean squared error: 0.11
# Variance score: 0.43
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Length, Sepal Width -> Petal Length
linear_reg('Sepal Width', 'Petal Width', 'Petal Length')
# Out:
# Coefficients:
#  [[0.09983647 0.42496915]]
# Mean squared error: 0.03
# Variance score: 0.95
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Sepal Width', 'Petal Length', 'Petal Width')
# Out:
# Coefficients:
#  [[-0.3641076   2.15042905]]
# Mean squared error: 0.16
# Variance score: 0.95
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Sepal Width', 'Sepal Length', 'Petal Width')
# Out:
# Coefficients:
#  [[0.39746806 0.97302236]]
# Mean squared error: 0.22
# Variance score: 0.67
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Sepal Width', 'Sepal Length', 'Petal Length')
# Out:
# Coefficients:
#  [[0.59652684 0.47225577]]
# Mean squared error: 0.12
# Variance score: 0.81
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Width', 'Petal Length', 'Sepal Length')
# Out:
# Coefficients:
#  [[1.72831893 0.55815873]]
# Mean squared error: 0.13
# Variance score: 0.96
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Width', 'Petal Length', 'Sepal Width')
# Out:
# Coefficients:
#  [[ 2.15042905 -0.3641076 ]]
# Mean squared error: 0.16
# Variance score: 0.95
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Width', 'Sepal Length', 'Sepal Length')
# Out:
# Coefficients:
#  [[0. 1.]]
# Mean squared error: 0.00
# Variance score: 1.00
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Width', 'Sepal Length', 'Sepal Width')
# Out:
# Coefficients:
#  [[0.97302236 0.39746806]]
# Mean squared error: 0.22
# Variance score: 0.67
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Sepal Length', 'Sepal Width')
# Out:
# Coefficients:
#  [[0.47225577 0.59652684]]
# Mean squared error: 0.12
# Variance score: 0.81
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Sepal Width', 'Sepal Length')
# Out:
# Coefficients:
#  [[-0.33482177  0.56159583]]
# Mean squared error: 0.11
# Variance score: 0.43
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Petal Width', 'Sepal Length')
# Out:
# Coefficients:
#  [[ 0.44528379 -0.07506892]]
# Mean squared error: 0.03
# Variance score: 0.95
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Petal Width', 'Sepal Width')
# Out:
# Coefficients:
#  [[0.42496915 0.09983647]]
# Mean squared error: 0.03
# Variance score: 0.95
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Sepal Width', 'Sepal Length')
# Out:
# Coefficients:
#  [[-0.33482177  0.56159583]]
# Mean squared error: 0.11
# Variance score: 0.43
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Petal Width', 'Sepal Length')
# Out:
# Coefficients:
#  [[ 0.44528379 -0.07506892]]
# Mean squared error: 0.03
# Variance score: 0.95
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
linear_reg('Petal Length', 'Sepal Width', 'Sepal Length')
# Out:
# Coefficients:
#  [[-0.33482177  0.56159583]]
# Mean squared error: 0.11
# Variance score: 0.43
# D:\Data\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sepal Length and Petal Length
linear_reg('Sepal Length', 'Petal Length', None)
# Out:
# Coefficients:
#  [[1.85938179]]
# Mean squared error: 0.80
# Variance score: 0.74
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
## Best Overall linear regression model
## THe module computed for Petal Length and Petal Width was the best overall model.Coefficiants [[0.41451925]], Mean squared error: 0.03 and Variance score: 0.94

# Sepal Width, Petal Length -> Petal Width
linear_reg('Petal Length', 'Petal Width', None)
# Out:
# Coefficients:
#  [[0.41451925]]
# Mean squared error: 0.03
# Variance score: 0.94
# D:\Data\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# D:\Data\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ### Based upon the linear models you generated,  which pair of features appear to be mostpredictive for one another?  Note that you can answer this question based upon the outputprovided for the linear models.

# %% [markdown]
# Based on the linear models i generated , i find the pair Petal Length and Petal Width appears to be most predictive for one another. The mean square error of 0.03 was the lowest of all i have got from pairwise modellings and variance 0.94 .This implies Petal length can be used to predict Petal width

# %% [markdown]
# ### Suppose you tried to generate a classification model on this dataset, but only after remov-ing the feature that you were best able to predict based upon other features.  How wouldremoving this feature affect the classification performance?

# %% [markdown]
# Petal width was the feature i was best able to predict based upon other features. But having said that Petal width can be mostly predicted with combination of other three features.This means the information contained in Petal Width should be regarded as redundant which wont affect classification performance much.
